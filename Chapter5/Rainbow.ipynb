# %% [markdown]
# Taken from: https://github.com/jfmengels/rainbowtable-python/

# %%
from hashlib import md5, sha1
from random import randrange

# %%
lettersLower = 'abcdefghijklmnopqrstuvwxyz'
lettersUpper = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
numbers = '0123456789'
allChars = lettersLower + lettersUpper + numbers

# %%
class RainbowTable:
    """
    Rainbow table: Structure to crack hashed passwords.
    """
    # Dictionary for finding hash functions by their name.
    hashFunctions = {
                   '': None,
       sha1.__name__ : sha1,
               'sha1': sha1,
        md5.__name__ : md5,
                'md5': md5,
    }
    
    def __init__(self, columns=0, chars="", pwdLength=0, func='', rows=1000):
        """
        Initialises the rainbow table.
        columns:    Length of a chain, i.e. the number of times the password 
                    at the start of the chain is hashed and reduced.
        chars:      List of characters covered.
        pwdLength:  Length of the passwords.
        func:       Name of the hashing function.
        rows:       Number of chains.
        """
        from RB import RBTree, rbnode
        self.table = RBTree()
        if columns > 0:
            self.columns = columns
            self.chars = chars
            self.pwdLength = pwdLength
            self.func = RainbowTable.hashFunctions[func]
            for i in range(rows):
                pwd = self.randomPassword()
                hashV = self.createChain(pwd)
                self.table.insert(hashV, pwd)
            
    def __repr__(self):
        """
        Prints the content of the table
        """
        return repr(self.table._root)
    
    def writeToFile(self, output):
        """
        Writes rainbow table into a file, so that it can be recovered at a
        different time later.
        output:  Name of the file to write to.
        """
        f = open(output, 'w')
        data = [self.columns, self.chars, self.pwdLength, self.func.__name__]
        data = [str(x) for x in data]
        f.write(" ".join(data))
        f.write("\n")
        f.write(repr(self))
        f.close()
    
    def readFromFile(self, inp):
        """
        Read a rainbow table from a file.
        input:  Name of the file to read from.
        """
        f = open(inp, "r")
        line = f.readline()
        line = line.strip().split(sep=" ", maxsplit=3)
        self.columns, self.chars, self.pwdLength, self.func = line
        self.columns = int(self.columns)
        self.pwdLength = int(self.pwdLength)
        self.func = RainbowTable.hashFunctions[self.func]
        line = f.readline()
        while line != '':
            pwd, hashV = line.strip().split(sep=" ", maxsplit=1)
            self.table.insert(hashV, pwd)
            line = f.readline()
        f.close()
    
    def _find(self, hashV):
        """
        Find the passwords in the table corresponding to the given hash.
        hashV:  Hash to find.
        Returns a list of corresponding starting passwords.
        """
        return self.table.search(hashV)
    
    def hashWord(self, word):
        """
        Hash a word.
        word:  Word to hash.
        Returns the hash of the word.
        """
        word = word.encode('utf-8')
        return self.func(word).hexdigest()
    
    def reduce(self, hashV, column):
        """
        Reduce a hash.
        hashV:  Hash to reduce.
        column:  Column to hash at.
        Returns a valid password.
        """
        results = []
        # Cast hash from str to int then decompose into bytes
        byteArray = self.getBytes(hashV)
        for i in range(self.pwdLength):
            index = byteArray[(i + column) % len(byteArray)]
            newChar = self.chars[index % len(self.chars)]
            results.append(newChar)
        return "".join(results)
        
    def getBytes(self, hashV):
        """
        Transforms a hash into a list of bytes.
        hashV:  Hash to transform into bytes.
        Returns a list of bytes.
        """
        results = []
        remaining = int(hashV, 16)
        while remaining > 0:
            results.append(remaining & 0xff)
            remaining >>= 8
        return results
    
    def createChain(self, pwd):
        """
        Creates a chain.
        pwd:  Password to start the chain with.
        Returns the hash at the end of the chain.
        """
        for col in range(self.columns):
            hashV = self.hashWord(pwd)
            pwd = self.reduce(hashV, col)
        return hashV
    
    def randomPassword(self):
        """
        Generates a random password.
        Return the generated password.
        """
#         from random import randrange
        pwd = ""
        charsLength = len(self.chars)
        for i in range(self.pwdLength):
            pwd += self.chars[randrange(charsLength)]
        return pwd
    
    def crackHash(self, startHash):
        """
        Tries to crack a hash.
        startHash:  Hash to crack.
        Returns the resulting password, if one is found, '' otherwise.
        """
        for col in range(self.columns, -1, -1):
            hashV = self._getFinalHash(startHash, col)
            pwdList = self._find(hashV)
            for pwd in pwdList:
                resPwd = self._findHashInChain(pwd, startHash)
                if resPwd != None:
                    return resPwd
        return ''
    
    def _getFinalHash(self, startHash, startCol):
        """
        Finds the hash at the end of a chain, starting from a hash
        and at a given column.
        startHash:  Hash to start with.
        startCol:  Column to start from.
        Returns the hash at the end of a chain.
        """
        hashV = startHash
        for col in range(startCol, self.columns-1):
            pwd = self.reduce(hashV, col)
            hashV = self.hashWord(pwd)
        return hashV
    
    def _findHashInChain(self, startPwd, startHash):
        """
        Tries to find a hash in a chain.
        startPwd:  Password at the beginning of a chain.
        startHash: Hash to find.
        Returns the corresponding password if one is found, None otherwise.
        """
        hashV = self.hashWord(startPwd)
        if hashV == startHash:
            return startPwd
        col = 0
        # Hash and reduce until the password has been found or the end of
        # the chain has been reached.
        while col < self.columns:
            pwd = self.reduce(hashV, col)
            hashV = self.hashWord(pwd)
            if hashV == startHash:
                # If the password has been found, return it
                return pwd
            col += 1
        # If the password hasn't been found, return None.
        return None
        
    def testWord(self, word):
        """
        Tries to find a password from its hash.
        word:  Word to find.
        Return the result of trying to crack the password of the hash.
        Note - Only for testing purposes.
        """
        return self.crackHash(self.hashWord(word))
    
    def testWords(self, words):
        """
        Tests a list of words from their hash.
        words:  List of words to find.
        Note - Only for testing purposes.
        """
        for word in words:
            print(word, self.crackHash(self.hashWord(word)))

# %%
rain = RainbowTable(100, lettersLower, 3, 'md5', rows=1000)

# %%
rain.testWord("abc")
# Out:
# 'abc'

# %%
rain.__repr__
# Out:
# <bound method RainbowTable.__repr__ of vwp 0201b3853db9215092666d1a6927d111
# snk 0201b3853db9215092666d1a6927d111
# ren 0201b3853db9215092666d1a6927d111
# wro 0201b3853db9215092666d1a6927d111
# wig 021cbd5becdba94344a0430b82ac9483
# yha 021cbd5becdba94344a0430b82ac9483
# nfa 021cbd5becdba94344a0430b82ac9483
# xob 021cbd5becdba94344a0430b82ac9483
# vao 021cbd5becdba94344a0430b82ac9483
# zmq 027e487c556461eb1ed9cd76b26d5102
# fbg 027e487c556461eb1ed9cd76b26d5102
# zgq 029ebc1540e3463a60dbcb0ef9463fbd
# czm 029ebc1540e3463a60dbcb0ef9463fbd
# ges 02d0bbdd9679407514f2aa8aa206cfff
# dtw 02d0bbdd9679407514f2aa8aa206cfff
# pff 02d0bbdd9679407514f2aa8aa206cfff
# sso 02ef7ce1bb30b06a930e1d1ea2f8771d
# xaf 02ef7ce1bb30b06a930e1d1ea2f8771d
# zri 02ef7ce1bb30b06a930e1d1ea2f8771d
# ehs 02ef7ce1bb30b06a930e1d1ea2f8771d
# axu 052c1846637cf022ecd1efcf6ef37999
# lbb 052c1846637cf022ecd1efcf6ef37999
# zvz 0630987beae1f40cf1508fa6ae80eca0
# twd 0630987beae1f40cf1508fa6ae80eca0
# jfh 0d2e00d2c8b42eefcd3b0b97be31dcaa
# aof 0d2e00d2c8b42eefcd3b0b97be31dcaa
# ght 0d2e00d2c8b42eefcd3b0b97be31dcaa
# ydl 0d2e00d2c8b42eefcd3b0b97be31dcaa
# ydl 0d2e00d2c8b42eefcd3b0b97be31dcaa
# xbb 0d2e00d2c8b42eefcd3b0b97be31dcaa
# xlg 0d2e00d2c8b42eefcd3b0b97be31dcaa
# odd 0d94687af4d9232aebe28598ac3ffc3b
# udh 0d94687af4d9232aebe28598ac3ffc3b
# muh 0d94687af4d9232aebe28598ac3ffc3b
# xmf 0d94687af4d9232aebe28598ac3ffc3b
# gim 0db0fa9dc3e5c61eb40c71d157ea9625
# cwd 14399851ac77479e5d764176d4b2dc1b
# xvm 14399851ac77479e5d764176d4b2dc1b
# usj 14399851ac77479e5d764176d4b2dc1b
# zyp 14399851ac77479e5d764176d4b2dc1b
# hgy 1490602b22192efb5f7ca4f616296afc
# ewr 1490602b22192efb5f7ca4f616296afc
# cea 1490602b22192efb5f7ca4f616296afc
# kev 1490602b22192efb5f7ca4f616296afc
# ypt 14c486a4f0894fb7437d405b730d9e5b
# ssx 15c38aa2581199246d9bd8889de2637f
# cox 15c38aa2581199246d9bd8889de2637f
# grp 15c38aa2581199246d9bd8889de2637f
# xjl 15c38aa2581199246d9bd8889de2637f
# oqj 15c38aa2581199246d9bd8889de2637f
# uqi 15c38aa2581199246d9bd8889de2637f
# jwq 15c38aa2581199246d9bd8889de2637f
# ouk 15c38aa2581199246d9bd8889de2637f
# kiw 15c38aa2581199246d9bd8889de2637f
# ouk 15c38aa2581199246d9bd8889de2637f
# yxw 15c38aa2581199246d9bd8889de2637f
# yqd 15c38aa2581199246d9bd8889de2637f
# zsm 183c5ec4581b85099655a71a7f46f955
# bhy 183c5ec4581b85099655a71a7f46f955
# uov 183c5ec4581b85099655a71a7f46f955
# eco 183c5ec4581b85099655a71a7f46f955
# jsv 183c5ec4581b85099655a71a7f46f955
# odf 1924e8be3761cc3abbb596d464499fed
# gye 1924e8be3761cc3abbb596d464499fed
# dwg 1924e8be3761cc3abbb596d464499fed
# zmm 1924e8be3761cc3abbb596d464499fed
# epy 1924e8be3761cc3abbb596d464499fed
# eav 1924e8be3761cc3abbb596d464499fed
# qxp 1924e8be3761cc3abbb596d464499fed
# zyn 1924e8be3761cc3abbb596d464499fed
# fnc 1924e8be3761cc3abbb596d464499fed
# mtt 1924e8be3761cc3abbb596d464499fed
# zfo 195961ac00c41e67f3f121fd4f059218
# jno 195961ac00c41e67f3f121fd4f059218
# vzx 1b001316d1e1b2669237299cfb6a2f7a
# qas 1b114711726f54da150952318892a1a8
# hsg 1b1466ae6a06d30a7fdc2a9e2a4e267d
# zvl 1b1466ae6a06d30a7fdc2a9e2a4e267d
# bac 1b1466ae6a06d30a7fdc2a9e2a4e267d
# mgm 1b1466ae6a06d30a7fdc2a9e2a4e267d
# rci 1b1466ae6a06d30a7fdc2a9e2a4e267d
# zuq 1b1466ae6a06d30a7fdc2a9e2a4e267d
# kav 1b1466ae6a06d30a7fdc2a9e2a4e267d
# vzy 1b1466ae6a06d30a7fdc2a9e2a4e267d
# pfd 1b1466ae6a06d30a7fdc2a9e2a4e267d
# oun 1b1466ae6a06d30a7fdc2a9e2a4e267d
# pbw 1b1466ae6a06d30a7fdc2a9e2a4e267d
# fot 1bc598041c7b50ff7c1688c9756f3859
# uob 1bc598041c7b50ff7c1688c9756f3859
# tpv 1bc598041c7b50ff7c1688c9756f3859
# lss 1bc598041c7b50ff7c1688c9756f3859
# zqa 1bc598041c7b50ff7c1688c9756f3859
# bkj 1bc598041c7b50ff7c1688c9756f3859
# eca 1bc598041c7b50ff7c1688c9756f3859
# lss 1bc598041c7b50ff7c1688c9756f3859
# jgo 1cb5105001ef368c5933689239efed41
# hgt 1dd83a36e51d9afee8e869ffb218b92a
# phv 1e3e0f1ecc6b5d7c344e7008d5db9a7e
# phv 1e3e0f1ecc6b5d7c344e7008d5db9a7e
# dsc 1f5c7fcfc3e9abdbbc258b4ab29de420
# ayy 1f5c7fcfc3e9abdbbc258b4ab29de420
# fii 242c3a9aed1859410980a2c293e0c66f
# nwk 253545033ba1e7bf5d22af6e2e34e586
# pga 261a77b4a49b2280187bfb803f53eaa1
# uda 261a77b4a49b2280187bfb803f53eaa1
# pji 266b601e8fdfa32712ba077bf4ed9bb2
# vwb 271e0f23731e31264b5ced055943b572
# ias 2885caf1e6337e1848d95ec798b39388
# wmq 2885caf1e6337e1848d95ec798b39388
# yla 2885caf1e6337e1848d95ec798b39388
# pkm 2b883e86ea676063418c6424966949ec
# tib 2b883e86ea676063418c6424966949ec
# mtr 2bb3ad2b85922e5f3bd5ae9511535d06
# lgg 2bb3ad2b85922e5f3bd5ae9511535d06
# wby 2bb3ad2b85922e5f3bd5ae9511535d06
# nij 2c915d470007c632db1125bf9c51baf0
# awu 2c915d470007c632db1125bf9c51baf0
# qla 2c915d470007c632db1125bf9c51baf0
# oau 2c915d470007c632db1125bf9c51baf0
# qzj 2c915d470007c632db1125bf9c51baf0
# gyw 2da790253022bd05cddda6d06bdc1e60
# tjv 2da790253022bd05cddda6d06bdc1e60
# ofm 2da790253022bd05cddda6d06bdc1e60
# iri 2da790253022bd05cddda6d06bdc1e60
# mpq 2da790253022bd05cddda6d06bdc1e60
# cvl 2da790253022bd05cddda6d06bdc1e60
# blu 2da790253022bd05cddda6d06bdc1e60
# rti 2da790253022bd05cddda6d06bdc1e60
# dis 2da790253022bd05cddda6d06bdc1e60
# phn 2da790253022bd05cddda6d06bdc1e60
# nyy 2da790253022bd05cddda6d06bdc1e60
# rnm 2da790253022bd05cddda6d06bdc1e60
# gba 2dd33aadc2e418848117df928876e353
# ezx 2dd33aadc2e418848117df928876e353
# fpa 2dd33aadc2e418848117df928876e353
# pqz 2dd33aadc2e418848117df928876e353
# lgk 2e929b889076e1fc84390fedefdaa7dd
# eqo 2e929b889076e1fc84390fedefdaa7dd
# eqo 2e929b889076e1fc84390fedefdaa7dd
# lpm 2e929b889076e1fc84390fedefdaa7dd
# nzb 2ef4d613a5cc85d9e2217a295b003815
# iru 30716e4a631dac4e2da783f4f7e99f97
# siv 30716e4a631dac4e2da783f4f7e99f97
# agq 30716e4a631dac4e2da783f4f7e99f97
# xjx 30716e4a631dac4e2da783f4f7e99f97
# lrg 3262d48df5d75e3452f0f16b313b7808
# sno 3262d48df5d75e3452f0f16b313b7808
# fqt 3262d48df5d75e3452f0f16b313b7808
# xhb 3262d48df5d75e3452f0f16b313b7808
# rph 3262d48df5d75e3452f0f16b313b7808
# qaa 3262d48df5d75e3452f0f16b313b7808
# nir 3262d48df5d75e3452f0f16b313b7808
# iew 3262d48df5d75e3452f0f16b313b7808
# lvc 3262d48df5d75e3452f0f16b313b7808
# znq 33f20f3ba79dd3047194a66fa8572b98
# frt 33f20f3ba79dd3047194a66fa8572b98
# ksh 33f20f3ba79dd3047194a66fa8572b98
# xdb 33f20f3ba79dd3047194a66fa8572b98
# xxz 340a050a9e85f17510b4939251ae4378
# cyw 340a050a9e85f17510b4939251ae4378
# iqo 340a050a9e85f17510b4939251ae4378
# fhw 340a050a9e85f17510b4939251ae4378
# iqo 340a050a9e85f17510b4939251ae4378
# hkq 340a050a9e85f17510b4939251ae4378
# bcs 340a050a9e85f17510b4939251ae4378
# nvv 348eec6bc2b3aca6947319d0c690b2e7
# ckf 348eec6bc2b3aca6947319d0c690b2e7
# qqo 348eec6bc2b3aca6947319d0c690b2e7
# vmk 348eec6bc2b3aca6947319d0c690b2e7
# xcl 348eec6bc2b3aca6947319d0c690b2e7
# ifo 34aa31768eba66cb70229c5636adaf73
# bbn 354317d0ca91ae2cd9042b8d9bcbcbac
# dgm 354317d0ca91ae2cd9042b8d9bcbcbac
# auh 354d067913e0c1cd1e28c79c69d341ed
# dgy 354d067913e0c1cd1e28c79c69d341ed
# gkx 354d067913e0c1cd1e28c79c69d341ed
# eny 37388f3c56188098785ddf70f5a8ab5a
# zed 3761e7920c97542314b1aa50434f9293
# vzp 3761e7920c97542314b1aa50434f9293
# acn 3761e7920c97542314b1aa50434f9293
# jvl 382d1621debe3fc01c97de984219c80f
# chi 382d1621debe3fc01c97de984219c80f
# puk 382d1621debe3fc01c97de984219c80f
# rry 382d1621debe3fc01c97de984219c80f
# wzs 382d1621debe3fc01c97de984219c80f
# fxq 382d1621debe3fc01c97de984219c80f
# ula 3926f242e7d77f42af08c402a9f42b19
# euh 3926f242e7d77f42af08c402a9f42b19
# ejf 3926f242e7d77f42af08c402a9f42b19
# fti 3926f242e7d77f42af08c402a9f42b19
# snu 3a63ee463554269952ed5200ff36ba77
# zzw 3b93015c8e40296af24e5028bb764a90
# eth 3c3a776920f9ec570e8422ba204a544a
# sar 3c3a776920f9ec570e8422ba204a544a
# lci 3c3a776920f9ec570e8422ba204a544a
# oqm 3c3a776920f9ec570e8422ba204a544a
# qlc 3dd086b59554fe33c1b8f051475b4b31
# aeb 3dd086b59554fe33c1b8f051475b4b31
# fzb 3dd086b59554fe33c1b8f051475b4b31
# usm 3dd086b59554fe33c1b8f051475b4b31
# xab 3dd086b59554fe33c1b8f051475b4b31
# uhd 3dd086b59554fe33c1b8f051475b4b31
# mxw 3dd086b59554fe33c1b8f051475b4b31
# usm 3dd086b59554fe33c1b8f051475b4b31
# ocn 3dd086b59554fe33c1b8f051475b4b31
# egm 3dd086b59554fe33c1b8f051475b4b31
# tzm 3dd086b59554fe33c1b8f051475b4b31
# vxs 3dd086b59554fe33c1b8f051475b4b31
# mys 3dd086b59554fe33c1b8f051475b4b31
# ltx 3dd086b59554fe33c1b8f051475b4b31
# flm 3dd086b59554fe33c1b8f051475b4b31
# glc 3efce9a2bfd7ef73ea7492cd04c288be
# quz 3fa0ca0f183120c91131ab7f480ffb90
# bhw 3fa0ca0f183120c91131ab7f480ffb90
# xim 3fa0ca0f183120c91131ab7f480ffb90
# dol 3fa0ca0f183120c91131ab7f480ffb90
# uoz 3fa0ca0f183120c91131ab7f480ffb90
# evu 3fa0ca0f183120c91131ab7f480ffb90
# nvq 3fa0ca0f183120c91131ab7f480ffb90
# klo 3fa0ca0f183120c91131ab7f480ffb90
# rsn 3fa0ca0f183120c91131ab7f480ffb90
# jqs 4102fd9d7e1f985a9def8feb905931e0
# xwb 423354803efb3ab609bf02f9537ba5d0
# xja 42adf07d48fdae1258dcb15249cca678
# raw 42e56d76aa0dadaee53a32954a71547c
# aie 42e56d76aa0dadaee53a32954a71547c
# evt 42e56d76aa0dadaee53a32954a71547c
# gnr 42e56d76aa0dadaee53a32954a71547c
# vjp 42e56d76aa0dadaee53a32954a71547c
# cgz 42e56d76aa0dadaee53a32954a71547c
# wwz 42e56d76aa0dadaee53a32954a71547c
# rkg 42efab72ae050ac8e22ac0ee8508cb9e
# mcu 42efab72ae050ac8e22ac0ee8508cb9e
# iam 42efab72ae050ac8e22ac0ee8508cb9e
# hfn 42efab72ae050ac8e22ac0ee8508cb9e
# oys 42efab72ae050ac8e22ac0ee8508cb9e
# ixy 42efab72ae050ac8e22ac0ee8508cb9e
# fgd 42efab72ae050ac8e22ac0ee8508cb9e
# ixu 42efab72ae050ac8e22ac0ee8508cb9e
# eaj 4349deefd26d15ef587a008b44612453
# roy 4349deefd26d15ef587a008b44612453
# eek 4349deefd26d15ef587a008b44612453
# nyd 4349deefd26d15ef587a008b44612453
# itj 443cafa43763ecef31a18198dcc04dc2
# hoc 443cafa43763ecef31a18198dcc04dc2
# itj 443cafa43763ecef31a18198dcc04dc2
# duc 443e5821b7a0d3f9b4b716a7554023bb
# wun 443e5821b7a0d3f9b4b716a7554023bb
# zrf 443e5821b7a0d3f9b4b716a7554023bb
# tba 443e5821b7a0d3f9b4b716a7554023bb
# djs 443e5821b7a0d3f9b4b716a7554023bb
# hwg 443e5821b7a0d3f9b4b716a7554023bb
# tqt 443e5821b7a0d3f9b4b716a7554023bb
# abv 443e5821b7a0d3f9b4b716a7554023bb
# vth 443e5821b7a0d3f9b4b716a7554023bb
# moi 44c1db397f99b875a442fef977d49812
# nxr 44c1db397f99b875a442fef977d49812
# ldb 44fdb916a558ef6739cfa6378de4995a
# heu 44fdb916a558ef6739cfa6378de4995a
# ort 44fdb916a558ef6739cfa6378de4995a
# kuo 45a5d2cb8e13de68db5da9f956138471
# bev 45a5d2cb8e13de68db5da9f956138471
# kah 45a5d2cb8e13de68db5da9f956138471
# otj 45a5d2cb8e13de68db5da9f956138471
# wkm 45a5d2cb8e13de68db5da9f956138471
# wgz 45a5d2cb8e13de68db5da9f956138471
# gwc 47a3e18c87d71db19d3d7857a1052462
# ymz 47a3e18c87d71db19d3d7857a1052462
# ryz 47a3e18c87d71db19d3d7857a1052462
# svx 47a3e18c87d71db19d3d7857a1052462
# pvt 47a3e18c87d71db19d3d7857a1052462
# oyt 47a3e18c87d71db19d3d7857a1052462
# ylh 47a3e18c87d71db19d3d7857a1052462
# sqp 47a3e18c87d71db19d3d7857a1052462
# avb 483237f0667d7f40038010db209c6200
# gvd 483237f0667d7f40038010db209c6200
# kuc 483237f0667d7f40038010db209c6200
# hof 483237f0667d7f40038010db209c6200
# eoz 483237f0667d7f40038010db209c6200
# mos 483237f0667d7f40038010db209c6200
# shl 483237f0667d7f40038010db209c6200
# exs 483237f0667d7f40038010db209c6200
# odk 483237f0667d7f40038010db209c6200
# fuq 487f3ba54ebe6bd564f333870902437d
# tva 487f3ba54ebe6bd564f333870902437d
# jcj 487f3ba54ebe6bd564f333870902437d
# ema 487f3ba54ebe6bd564f333870902437d
# qby 49acdce106ade4fe480ba3753b9bf756
# hmd 49acdce106ade4fe480ba3753b9bf756
# ara 49acdce106ade4fe480ba3753b9bf756
# ara 49acdce106ade4fe480ba3753b9bf756
# tjj 4a5354b760bac2b17870a7eb47dfc46a
# wya 4a5354b760bac2b17870a7eb47dfc46a
# fei 4a5354b760bac2b17870a7eb47dfc46a
# uwq 4a5354b760bac2b17870a7eb47dfc46a
# jzn 4a5354b760bac2b17870a7eb47dfc46a
# duk 4a594de09295819539bd489716b4c76a
# bmh 4a594de09295819539bd489716b4c76a
# wqq 4a60eeb31b165d9f2127b126fc0c6ccb
# aca 4a60eeb31b165d9f2127b126fc0c6ccb
# wdf 4a60eeb31b165d9f2127b126fc0c6ccb
# jxt 4a60eeb31b165d9f2127b126fc0c6ccb
# cuw 4a60eeb31b165d9f2127b126fc0c6ccb
# kwi 4a60eeb31b165d9f2127b126fc0c6ccb
# zfy 4a60eeb31b165d9f2127b126fc0c6ccb
# cwx 4ac1dd9204946a33d4c2ae9f3ab6e90d
# jdl 4d82290a649a51f83f17a2c9bffd66c7
# lpj 4d82290a649a51f83f17a2c9bffd66c7
# jfi 4d82290a649a51f83f17a2c9bffd66c7
# tmr 4d82290a649a51f83f17a2c9bffd66c7
# zny 4ed3c4b22349dd5a28b271282bdc98f6
# glk 4f074185fba7c476ec26ac7d862418fb
# yug 4fbe49be988adf8095181ca7aeb4952f
# nlk 4fbe49be988adf8095181ca7aeb4952f
# jpb 501df69458b6d7d2ad8cc8e13e84bc56
# cnd 501df69458b6d7d2ad8cc8e13e84bc56
# jqj 501df69458b6d7d2ad8cc8e13e84bc56
# gsx 52ba8e68faf75a9771420d45fda64955
# pqf 52ba8e68faf75a9771420d45fda64955
# sxi 52ba8e68faf75a9771420d45fda64955
# fnn 52ba8e68faf75a9771420d45fda64955
# shf 52ba8e68faf75a9771420d45fda64955
# shf 52ba8e68faf75a9771420d45fda64955
# oug 541f98322eaea41f2b2e3d023972f098
# unk 541f98322eaea41f2b2e3d023972f098
# tsg 541f98322eaea41f2b2e3d023972f098
# gth 54fd226a01b82a1152e63422011dd372
# gsp 557c9246028b2b315e811a8ceb7691bf
# xwt 557c9246028b2b315e811a8ceb7691bf
# krt 557c9246028b2b315e811a8ceb7691bf
# osc 557c9246028b2b315e811a8ceb7691bf
# gou 557c9246028b2b315e811a8ceb7691bf
# gsp 557c9246028b2b315e811a8ceb7691bf
# wng 557c9246028b2b315e811a8ceb7691bf
# llx 557c9246028b2b315e811a8ceb7691bf
# wrz 557c9246028b2b315e811a8ceb7691bf
# gsr 557c9246028b2b315e811a8ceb7691bf
# nch 558f9faa033e9768f07a9c94a1918fce
# mpa 558f9faa033e9768f07a9c94a1918fce
# atg 558f9faa033e9768f07a9c94a1918fce
# dhn 558f9faa033e9768f07a9c94a1918fce
# xjc 558f9faa033e9768f07a9c94a1918fce
# iwv 558f9faa033e9768f07a9c94a1918fce
# ici 558f9faa033e9768f07a9c94a1918fce
# hlk 558f9faa033e9768f07a9c94a1918fce
# ttp 558f9faa033e9768f07a9c94a1918fce
# zxd 565c6b6750d66cd7d22596e68be9f518
# ier 565c6b6750d66cd7d22596e68be9f518
# zxd 565c6b6750d66cd7d22596e68be9f518
# wrv 587e6a7556ea454af6a44bc6c021dba7
# njq 587e6a7556ea454af6a44bc6c021dba7
# zef 587e6a7556ea454af6a44bc6c021dba7
# rtx 587e6a7556ea454af6a44bc6c021dba7
# ohl 587e6a7556ea454af6a44bc6c021dba7
# txe 587e6a7556ea454af6a44bc6c021dba7
# mif 587e6a7556ea454af6a44bc6c021dba7
# com 587e6a7556ea454af6a44bc6c021dba7
# bkk 5a2fe5fad6e4b381ba14fa034a1e6a96
# gvp 5a2fe5fad6e4b381ba14fa034a1e6a96
# zru 5a2fe5fad6e4b381ba14fa034a1e6a96
# yfx 5c04f58b260c713495e0736235927b0c
# gzh 5c04f58b260c713495e0736235927b0c
# bpx 5ce38ae809793c4df12c7782b7f0f93a
# xlz 5db06414e265179b281c1f3f857e71ad
# wzw 5db06414e265179b281c1f3f857e71ad
# ujm 5ecaf0d3af3004219bc6b5907d19b6d9
# qid 5ecaf0d3af3004219bc6b5907d19b6d9
# acb 5ecaf0d3af3004219bc6b5907d19b6d9
# pye 615a61f69b9c5340db527c692b03eb43
# stf 615a61f69b9c5340db527c692b03eb43
# nuy 61b54070e792f37e7749195343cfb67e
# psq 6201912346f3222a805dd6f9a1afeb73
# nvi 62f037d09f3863ad158f150d7b85692e
# vie 62f037d09f3863ad158f150d7b85692e
# rah 6377268767f065492a3d9fa70639178e
# hyx 6377268767f065492a3d9fa70639178e
# gkh 6377268767f065492a3d9fa70639178e
# tcn 6377268767f065492a3d9fa70639178e
# llk 6377268767f065492a3d9fa70639178e
# tht 6377268767f065492a3d9fa70639178e
# for 63a77021ce2c11562e4cb7bc0d5875ab
# zmo 63a77021ce2c11562e4cb7bc0d5875ab
# wjt 63f37e4d9afe47d95d02c7a305631423
# rtd 63f37e4d9afe47d95d02c7a305631423
# evj 63f37e4d9afe47d95d02c7a305631423
# qtb 63f37e4d9afe47d95d02c7a305631423
# xnc 65d790ae0e9c696da48f8b5ef40a7029
# asr 65d790ae0e9c696da48f8b5ef40a7029
# vzg 66f7c3a8b73e1d5e52cb7131b356840b
# yvp 66f7c3a8b73e1d5e52cb7131b356840b
# odq 66f7c3a8b73e1d5e52cb7131b356840b
# due 676a4cf46754b50a09c3c7a16a38c0aa
# vci 676a4cf46754b50a09c3c7a16a38c0aa
# ffv 676a4cf46754b50a09c3c7a16a38c0aa
# rrc 67ab64f5349e510eaaa72b6d432ade4b
# ipb 67ab64f5349e510eaaa72b6d432ade4b
# kra 682b53c8552ec0d1f83e44e2dfb56504
# kra 682b53c8552ec0d1f83e44e2dfb56504
# tnb 692cea6c0bfa01c0091ed12bc1d019b2
# rao 692cea6c0bfa01c0091ed12bc1d019b2
# iob 6a1b2de69eeb9a037ea23de6b529394d
# jgt 6a1b2de69eeb9a037ea23de6b529394d
# zxm 6a1b2de69eeb9a037ea23de6b529394d
# mum 6a1b2de69eeb9a037ea23de6b529394d
# tfu 6a1b2de69eeb9a037ea23de6b529394d
# idr 6a1b2de69eeb9a037ea23de6b529394d
# dai 6a1b2de69eeb9a037ea23de6b529394d
# qri 6a49f67ed8e5e478391b7496381f4047
# dyu 6a49f67ed8e5e478391b7496381f4047
# umq 6a49f67ed8e5e478391b7496381f4047
# fxd 6a49f67ed8e5e478391b7496381f4047
# mao 6a49f67ed8e5e478391b7496381f4047
# snc 6a49f67ed8e5e478391b7496381f4047
# fje 6a87284914054e1ba5d1d288c1b09f43
# qtq 6aa5590d1e35198ab1badbdec503a8d0
# qvg 6aa5590d1e35198ab1badbdec503a8d0
# moo 6aa5590d1e35198ab1badbdec503a8d0
# gek 6bd2709008aa3ed65bcf917bdbe9b3ce
# jkc 6bd2709008aa3ed65bcf917bdbe9b3ce
# bik 6bd2709008aa3ed65bcf917bdbe9b3ce
# xcb 6bd2709008aa3ed65bcf917bdbe9b3ce
# bda 6bd2709008aa3ed65bcf917bdbe9b3ce
# hnb 6c4b0d9d96b8cba9d5cc8ea2d8f85b84
# tai 6c4b0d9d96b8cba9d5cc8ea2d8f85b84
# fih 6c4b0d9d96b8cba9d5cc8ea2d8f85b84
# xfz 6c4b0d9d96b8cba9d5cc8ea2d8f85b84
# sie 6dd2abc202d5c30b152e755426f9cbd1
# uls 6dd2abc202d5c30b152e755426f9cbd1
# bwr 6dd2abc202d5c30b152e755426f9cbd1
# egk 6dd2abc202d5c30b152e755426f9cbd1
# ukp 6ec5c762eab34058ae6fe87c33c03330
# sdk 6ec5c762eab34058ae6fe87c33c03330
# dbh 6ec5c762eab34058ae6fe87c33c03330
# nku 704d635a37ec52e615a7f9a3c8925d87
# ita 718303225f998f9c5f73294a8d545466
# bha 718303225f998f9c5f73294a8d545466
# bha 718303225f998f9c5f73294a8d545466
# ine 728996853f295d0206575099f828878b
# vnt 728996853f295d0206575099f828878b
# ggi 7375d18c337cac2594b75346e2d13d32
# toc 7375d18c337cac2594b75346e2d13d32
# sqs 7375d18c337cac2594b75346e2d13d32
# tek 7375d18c337cac2594b75346e2d13d32
# jsy 7375d18c337cac2594b75346e2d13d32
# iwl 7375d18c337cac2594b75346e2d13d32
# kld 7375d18c337cac2594b75346e2d13d32
# awo 7375d18c337cac2594b75346e2d13d32
# vmp 7375d18c337cac2594b75346e2d13d32
# jjd 7375d18c337cac2594b75346e2d13d32
# iki 7375d18c337cac2594b75346e2d13d32
# nnj 73ca0bd0b089c177d3134dd772ab70f4
# wvh 73ca0bd0b089c177d3134dd772ab70f4
# qdm 73ca0bd0b089c177d3134dd772ab70f4
# bbp 73fe8f327b36932eb9d58b02ca722062
# zuw 73fe8f327b36932eb9d58b02ca722062
# cey 73fe8f327b36932eb9d58b02ca722062
# orn 73fe8f327b36932eb9d58b02ca722062
# bek 7479338d4e6a6508c821fa4f4b621b36
# zlw 7479338d4e6a6508c821fa4f4b621b36
# fpd 7479338d4e6a6508c821fa4f4b621b36
# biq 7479338d4e6a6508c821fa4f4b621b36
# unu 7479338d4e6a6508c821fa4f4b621b36
# zvy 7479338d4e6a6508c821fa4f4b621b36
# him 7479338d4e6a6508c821fa4f4b621b36
# cew 7479338d4e6a6508c821fa4f4b621b36
# axb 7479338d4e6a6508c821fa4f4b621b36
# fxm 7479338d4e6a6508c821fa4f4b621b36
# aic 7479338d4e6a6508c821fa4f4b621b36
# gxj 7479338d4e6a6508c821fa4f4b621b36
# fwx 74e1e420da1716ae52ac3ed6655417d0
# lpo 74e1e420da1716ae52ac3ed6655417d0
# hvd 74e1e420da1716ae52ac3ed6655417d0
# dfu 74e1e420da1716ae52ac3ed6655417d0
# nbs 74e1e420da1716ae52ac3ed6655417d0
# jpp 74e1e420da1716ae52ac3ed6655417d0
# dem 74e1e420da1716ae52ac3ed6655417d0
# jxe 74e1e420da1716ae52ac3ed6655417d0
# grh 74e1e420da1716ae52ac3ed6655417d0
# lpo 74e1e420da1716ae52ac3ed6655417d0
# rod 74e1e420da1716ae52ac3ed6655417d0
# yze 7606517b6f62538f9ad5d84832bf0930
# sjj 7606517b6f62538f9ad5d84832bf0930
# iwa 7606517b6f62538f9ad5d84832bf0930
# evv 7606517b6f62538f9ad5d84832bf0930
# ush 7606517b6f62538f9ad5d84832bf0930
# rgi 76fc0e5cae61e9b3a54b585f3b46769d
# oeo 76fc0e5cae61e9b3a54b585f3b46769d
# omc 76fc0e5cae61e9b3a54b585f3b46769d
# ovv 76fc0e5cae61e9b3a54b585f3b46769d
# tqn 76fc0e5cae61e9b3a54b585f3b46769d
# jzj 787f2bff3a2bfce9dc670242b1abdfa4
# trh 787f2bff3a2bfce9dc670242b1abdfa4
# iby 787f2bff3a2bfce9dc670242b1abdfa4
# wae 787f2bff3a2bfce9dc670242b1abdfa4
# yqp 787f2bff3a2bfce9dc670242b1abdfa4
# xfw 787f2bff3a2bfce9dc670242b1abdfa4
# fee 78a84f93d185dcf4c59771263b3f1af3
# aph 78a84f93d185dcf4c59771263b3f1af3
# adz 799263f066ddd0e1f49b993d06a38a8c
# fip 799263f066ddd0e1f49b993d06a38a8c
# wbz 799263f066ddd0e1f49b993d06a38a8c
# ods 7a204dac5b31b842fd13d3935316a803
# lfn 7a204dac5b31b842fd13d3935316a803
# occ 7a204dac5b31b842fd13d3935316a803
# crt 7a2a9bd7deef151cdb5bb04bc0aaccb7
# shm 7a2a9bd7deef151cdb5bb04bc0aaccb7
# bkf 7b68ebe8469500f36d4da69451761052
# qhh 7b68ebe8469500f36d4da69451761052
# nur 7b68ebe8469500f36d4da69451761052
# bxe 81708afb81a9cafbadce1bd310ba23b8
# pym 81922c6e7c4bdebebd7be669d60b7a59
# ayi 81922c6e7c4bdebebd7be669d60b7a59
# sjc 81922c6e7c4bdebebd7be669d60b7a59
# mfs 81922c6e7c4bdebebd7be669d60b7a59
# egc 81922c6e7c4bdebebd7be669d60b7a59
# fqw 81a59440639979f7049c8a4e86bf82ba
# hxj 81a59440639979f7049c8a4e86bf82ba
# trv 81a59440639979f7049c8a4e86bf82ba
# eoa 81a59440639979f7049c8a4e86bf82ba
# udz 81a59440639979f7049c8a4e86bf82ba
# sde 81a59440639979f7049c8a4e86bf82ba
# ttq 81a59440639979f7049c8a4e86bf82ba
# gfy 81a59440639979f7049c8a4e86bf82ba
# ecq 81a59440639979f7049c8a4e86bf82ba
# qnu 81a59440639979f7049c8a4e86bf82ba
# qml 81a59440639979f7049c8a4e86bf82ba
# vjt 81a59440639979f7049c8a4e86bf82ba
# cgm 81f542a1a8c9779708ff744f63a49a22
# pid 81f542a1a8c9779708ff744f63a49a22
# ouc 81f542a1a8c9779708ff744f63a49a22
# neg 81f542a1a8c9779708ff744f63a49a22
# lfb 81f542a1a8c9779708ff744f63a49a22
# mws 81f542a1a8c9779708ff744f63a49a22
# agz 81f542a1a8c9779708ff744f63a49a22
# jqq 8230612276f81887429d757e66ebe9c2
# uas 8230612276f81887429d757e66ebe9c2
# imu 8230612276f81887429d757e66ebe9c2
# knm 82ff78bccb964a849c051f5a9ceff9e8
# xql 82ff78bccb964a849c051f5a9ceff9e8
# irv 82ff78bccb964a849c051f5a9ceff9e8
# dww 82ff78bccb964a849c051f5a9ceff9e8
# hth 82ff78bccb964a849c051f5a9ceff9e8
# fbl 82ff78bccb964a849c051f5a9ceff9e8
# bul 82ff78bccb964a849c051f5a9ceff9e8
# idj 83059a5a2ee38c7f6a6dff7d0edafd89
# bgy 83059a5a2ee38c7f6a6dff7d0edafd89
# hea 8504c4c86932836f57ad55f7c5f1f7ef
# ali 8772bd6d2f745189dbde651e267502ea
# lto 8772bd6d2f745189dbde651e267502ea
# ucz 8772bd6d2f745189dbde651e267502ea
# ucu 8772bd6d2f745189dbde651e267502ea
# lsj 8772bd6d2f745189dbde651e267502ea
# bnj 8772bd6d2f745189dbde651e267502ea
# pjf 8772bd6d2f745189dbde651e267502ea
# pot 8772bd6d2f745189dbde651e267502ea
# whq 87b7110c9a93826b50f500b0b2c9077a
# igz 87b7110c9a93826b50f500b0b2c9077a
# ded 87b7110c9a93826b50f500b0b2c9077a
# wfu 87b7110c9a93826b50f500b0b2c9077a
# obp 8860a2a2cb5dd6107b1d51769fb9468d
# btj 8860a2a2cb5dd6107b1d51769fb9468d
# wne 8860a2a2cb5dd6107b1d51769fb9468d
# iax 8860a2a2cb5dd6107b1d51769fb9468d
# krv 8860a2a2cb5dd6107b1d51769fb9468d
# wsy 8860a2a2cb5dd6107b1d51769fb9468d
# imc 8860a2a2cb5dd6107b1d51769fb9468d
# ohp 8860a2a2cb5dd6107b1d51769fb9468d
# sad 8860a2a2cb5dd6107b1d51769fb9468d
# mcv 8a0bdbd84559fcb34e1aa8fb6f52378c
# wzk 8a0bdbd84559fcb34e1aa8fb6f52378c
# aod 8a2c4d53749afcabb2455b786dda05a6
# ahp 8a2c4d53749afcabb2455b786dda05a6
# ldw 8a2c4d53749afcabb2455b786dda05a6
# trp 8a2c4d53749afcabb2455b786dda05a6
# wah 8a2c4d53749afcabb2455b786dda05a6
# lrq 8a2c4d53749afcabb2455b786dda05a6
# qpc 8abf6b60337506765c9598469956dc26
# buh 8abf6b60337506765c9598469956dc26
# xwj 8abf6b60337506765c9598469956dc26
# yzq 8abf6b60337506765c9598469956dc26
# xxr 8abf6b60337506765c9598469956dc26
# gwl 8afff7417018b8f351b6ce1fb9f2c1c3
# hmp 8afff7417018b8f351b6ce1fb9f2c1c3
# zby 8b83e0f1cfd0d896920b1cc6969024ef
# coz 8b83e0f1cfd0d896920b1cc6969024ef
# dln 8b83e0f1cfd0d896920b1cc6969024ef
# epr 8b83e0f1cfd0d896920b1cc6969024ef
# pqv 8cf9c943547923e7e7712b0a0d2ba7a5
# ctr 8cf9c943547923e7e7712b0a0d2ba7a5
# ctr 8cf9c943547923e7e7712b0a0d2ba7a5
# ctr 8cf9c943547923e7e7712b0a0d2ba7a5
# pil 8cf9c943547923e7e7712b0a0d2ba7a5
# lii 8cf9c943547923e7e7712b0a0d2ba7a5
# rze 8d2cc35e70deca8505ee61f089a46ec4
# ywa 8d2cc35e70deca8505ee61f089a46ec4
# iwb 8d2cc35e70deca8505ee61f089a46ec4
# fin 8d6d9d89771cf702a92e091768312107
# sgd 8d6d9d89771cf702a92e091768312107
# zpv 8d6d9d89771cf702a92e091768312107
# waa 8d9b897f45b9f6babb9a3e48d51dcde5
# vdm 8d9b897f45b9f6babb9a3e48d51dcde5
# qks 8d9b897f45b9f6babb9a3e48d51dcde5
# fsc 8df0acbab8651ee5e4e21eeb9709f138
# ezw 8e083aeab52b9fdb6a73749c0bba77a8
# cty 8e083aeab52b9fdb6a73749c0bba77a8
# aqb 8e083aeab52b9fdb6a73749c0bba77a8
# ute 8e083aeab52b9fdb6a73749c0bba77a8
# klw 8e083aeab52b9fdb6a73749c0bba77a8
# lel 8e083aeab52b9fdb6a73749c0bba77a8
# yql 8f730c864734fbb7d0dc821bd7b29610
# hoh 8f730c864734fbb7d0dc821bd7b29610
# vce 8f730c864734fbb7d0dc821bd7b29610
# wiu 8f730c864734fbb7d0dc821bd7b29610
# ulu 8f730c864734fbb7d0dc821bd7b29610
# eaq 8f730c864734fbb7d0dc821bd7b29610
# ukh 8f730c864734fbb7d0dc821bd7b29610
# crq 8f730c864734fbb7d0dc821bd7b29610
# uus 91566bf33986d88ec33b79b7797e58e2
# ice 91566bf33986d88ec33b79b7797e58e2
# vnh 91566bf33986d88ec33b79b7797e58e2
# buv 91566bf33986d88ec33b79b7797e58e2
# pmn 91566bf33986d88ec33b79b7797e58e2
# nrw 91566bf33986d88ec33b79b7797e58e2
# dac 925904eff1859a82ccf49f5f2a450980
# pwp 925904eff1859a82ccf49f5f2a450980
# sbm 92849aeec004d64f3cdd984a81100ee7
# ryl 92849aeec004d64f3cdd984a81100ee7
# lam 92849aeec004d64f3cdd984a81100ee7
# ryl 92849aeec004d64f3cdd984a81100ee7
# pmv 9348ae7851cf3ba798d9564ef308ec25
# tfe 9348ae7851cf3ba798d9564ef308ec25
# vrv 9348ae7851cf3ba798d9564ef308ec25
# ryj 9348ae7851cf3ba798d9564ef308ec25
# bqp 9348ae7851cf3ba798d9564ef308ec25
# jrc 9348ae7851cf3ba798d9564ef308ec25
# ytd 9348ae7851cf3ba798d9564ef308ec25
# jrc 9348ae7851cf3ba798d9564ef308ec25
# hll 9348ae7851cf3ba798d9564ef308ec25
# mrl 93fcef1bd7aeaa8bb840fe5eee7e065e
# llo 9616ce3f4183c5e7241e7a9bb3a192d0
# xlk 96466301bed4aeef20378fe7bb5277e6
# csa 96466301bed4aeef20378fe7bb5277e6
# poo 96466301bed4aeef20378fe7bb5277e6
# ovn 96b93113f631af312abb144481ca86db
# vwa 96b93113f631af312abb144481ca86db
# xsh 9727479252e200330c1e9cc9a3fea96e
# ipr 972890943b6cbe30175f19ee122669db
# qts 98ddde66ca35468178835270933b7c4c
# fos 99e36bdf9c656e89f03687825285fed1
# ruz 99e36bdf9c656e89f03687825285fed1
# rem 99e36bdf9c656e89f03687825285fed1
# zrt 9a646feddd984d22579fc7e34b579735
# tgw 9a646feddd984d22579fc7e34b579735
# ucb 9a646feddd984d22579fc7e34b579735
# tgw 9a646feddd984d22579fc7e34b579735
# srg 9edd26d3ca4cc77d16be8766224df539
# yni 9edd26d3ca4cc77d16be8766224df539
# acs 9edd26d3ca4cc77d16be8766224df539
# uro 9f11c10b5e21488df16be85ab0a78cd4
# ode a00fce33b6a9d13778a9f360cbb0fe10
# swr a00fce33b6a9d13778a9f360cbb0fe10
# cje a00fce33b6a9d13778a9f360cbb0fe10
# uki a00fce33b6a9d13778a9f360cbb0fe10
# enb a00fce33b6a9d13778a9f360cbb0fe10
# vfs a00fce33b6a9d13778a9f360cbb0fe10
# vfa a00fce33b6a9d13778a9f360cbb0fe10
# fvc a02225acec4e8b5661f4d3674bea0995
# tlv a08083d1fbea4c0660fb02a493fb196c
# emb a08083d1fbea4c0660fb02a493fb196c
# nvt a2fffbf435405a98cec152b2a7d7f882
# rhv a2fffbf435405a98cec152b2a7d7f882
# dqb a2fffbf435405a98cec152b2a7d7f882
# fzx a2fffbf435405a98cec152b2a7d7f882
# hal a2fffbf435405a98cec152b2a7d7f882
# fil a2fffbf435405a98cec152b2a7d7f882
# aoc a2fffbf435405a98cec152b2a7d7f882
# rhv a2fffbf435405a98cec152b2a7d7f882
# fzx a2fffbf435405a98cec152b2a7d7f882
# cpo a2fffbf435405a98cec152b2a7d7f882
# efw a2fffbf435405a98cec152b2a7d7f882
# vjc a3aca2964e72000eea4c56cb341002a4
# kzo a3aca2964e72000eea4c56cb341002a4
# ggj a5e669e9a3073f1384994f3b02576748
# ktz a5e669e9a3073f1384994f3b02576748
# pbn a5e669e9a3073f1384994f3b02576748
# ktn a780f0ea43ae90b597b386968e09ab04
# yap a7939d043567ee90a9f1febb314e563d
# ygt a7939d043567ee90a9f1febb314e563d
# hvt a7f38035beaefe30a11d6f601051230f
# fwv a7f38035beaefe30a11d6f601051230f
# hvt a7f38035beaefe30a11d6f601051230f
# zac a88b77bc0c726aab3ee94f7a6b631d7f
# myw a88b77bc0c726aab3ee94f7a6b631d7f
# ecy a88b77bc0c726aab3ee94f7a6b631d7f
# bmi a88b77bc0c726aab3ee94f7a6b631d7f
# wrn a88b77bc0c726aab3ee94f7a6b631d7f
# mgu a892c55cd0278b6a962a708044da8625
# kdb a9094dce0908f5fd61ac760e4b51f380
# vlp a9094dce0908f5fd61ac760e4b51f380
# kqy aab26cd1276d7ffdd5066e1b3010a183
# hdn aab26cd1276d7ffdd5066e1b3010a183
# gza aab26cd1276d7ffdd5066e1b3010a183
# tnf ab2f0f023460c81e7ff570315684cef2
# mfz ab2f0f023460c81e7ff570315684cef2
# wfm ad910c248fbe85c146fd255292501007
# gmw ad910c248fbe85c146fd255292501007
# flp ad910c248fbe85c146fd255292501007
# ttw ad910c248fbe85c146fd255292501007
# ykj ade0721065f344170587ae5a0cfaa286
# aog ade0721065f344170587ae5a0cfaa286
# ifb ade0721065f344170587ae5a0cfaa286
# dso ae3ecae4765c8a764c4231ecb0c7bb1c
# bbc ae3ecae4765c8a764c4231ecb0c7bb1c
# lhj ae3ecae4765c8a764c4231ecb0c7bb1c
# crf aeec645249be520c2b20c9d4b33912ee
# iel aeec645249be520c2b20c9d4b33912ee
# lcg aeec645249be520c2b20c9d4b33912ee
# meo aeec645249be520c2b20c9d4b33912ee
# dpi aeec645249be520c2b20c9d4b33912ee
# djr aeec645249be520c2b20c9d4b33912ee
# mkp af19ec6cf4bf736f77372faa0b80143c
# mkp af19ec6cf4bf736f77372faa0b80143c
# svd b067b3d3054d8868c950e1946300a3f4
# ixc b067b3d3054d8868c950e1946300a3f4
# lym b213e73e577729cd2a09f49ac5e04b29
# gnj b33b98e4927e314775a851f38a704900
# tzt b33b98e4927e314775a851f38a704900
# nql b5aaa055318011e29cc4b0dd8946ec61
# hak b5fca0b63c6347b443180b87696bf5be
# rbc b5fe8e8e5410690e6ec70d3762810451
# byv b5fe8e8e5410690e6ec70d3762810451
# oyb b5fe8e8e5410690e6ec70d3762810451
# lqz b5fe8e8e5410690e6ec70d3762810451
# efe b60088c65d0afcdb5a79c56aee07ca9e
# iau b60088c65d0afcdb5a79c56aee07ca9e
# wav b60088c65d0afcdb5a79c56aee07ca9e
# kri b60088c65d0afcdb5a79c56aee07ca9e
# mrp b60088c65d0afcdb5a79c56aee07ca9e
# efe b60088c65d0afcdb5a79c56aee07ca9e
# bef b6ff1e02a41535337f28b3d8b18ccde8
# bef b6ff1e02a41535337f28b3d8b18ccde8
# cti b71fd2cd6fd8063840f0e27645ab1981
# dql b7cbcb43c5196fea8fe0074c1ff01b32
# bva b7cbcb43c5196fea8fe0074c1ff01b32
# zuv b7cbcb43c5196fea8fe0074c1ff01b32
# kpm b7cbcb43c5196fea8fe0074c1ff01b32
# gug b7cbcb43c5196fea8fe0074c1ff01b32
# xqg b7cbcb43c5196fea8fe0074c1ff01b32
# ajb b7cbcb43c5196fea8fe0074c1ff01b32
# dlz b7cbcb43c5196fea8fe0074c1ff01b32
# hot b7cbcb43c5196fea8fe0074c1ff01b32
# zuv b7cbcb43c5196fea8fe0074c1ff01b32
# nym b7cbcb43c5196fea8fe0074c1ff01b32
# ftr b7cbcb43c5196fea8fe0074c1ff01b32
# mhf b7cbcb43c5196fea8fe0074c1ff01b32
# kxu b7cbcb43c5196fea8fe0074c1ff01b32
# tab b7cbcb43c5196fea8fe0074c1ff01b32
# ejx b92d90ee77f900511b28ce99a99c67b8
# veo b92d90ee77f900511b28ce99a99c67b8
# vbr b93776ca54178e43b3a87c6e51d048cc
# cmp b93776ca54178e43b3a87c6e51d048cc
# jtw ba305ee3459ae3827d6e219a6de03e73
# mpf ba6fec44da12d464c9fd3d305a20629a
# gwb ba6fec44da12d464c9fd3d305a20629a
# kkz ba6fec44da12d464c9fd3d305a20629a
# kkz ba6fec44da12d464c9fd3d305a20629a
# xvg ba6fec44da12d464c9fd3d305a20629a
# ofb ba6fec44da12d464c9fd3d305a20629a
# qqp ba6fec44da12d464c9fd3d305a20629a
# iyi bd44d3a77bc2ecfe85d183cc9a9af8ba
# iyi bd44d3a77bc2ecfe85d183cc9a9af8ba
# cjh c00687fa6a20757e9048706f1465221f
# nqz c0ad6d3c4c1046727c80d0f70decb037
# esh c10bc694138e2d7f8d99757e2bc829b7
# zex c10bc694138e2d7f8d99757e2bc829b7
# lhv c10bc694138e2d7f8d99757e2bc829b7
# ard c10bc694138e2d7f8d99757e2bc829b7
# oru c10bc694138e2d7f8d99757e2bc829b7
# kgm c10bc694138e2d7f8d99757e2bc829b7
# vaq c10bc694138e2d7f8d99757e2bc829b7
# ety c10bc694138e2d7f8d99757e2bc829b7
# zha c10bc694138e2d7f8d99757e2bc829b7
# qwm c46e224feb33a5fcdb2f031b9a595be2
# zte c46e224feb33a5fcdb2f031b9a595be2
# doo c46e224feb33a5fcdb2f031b9a595be2
# sfn c46e224feb33a5fcdb2f031b9a595be2
# pfr c4b8ce1b67d38aa98345f108f9f529ca
# jcq c4b8ce1b67d38aa98345f108f9f529ca
# vnl c4b8ce1b67d38aa98345f108f9f529ca
# svo c4b8ce1b67d38aa98345f108f9f529ca
# zec c4b8ce1b67d38aa98345f108f9f529ca
# mzp c4b8ce1b67d38aa98345f108f9f529ca
# pvh c4b8ce1b67d38aa98345f108f9f529ca
# noo c4b8ce1b67d38aa98345f108f9f529ca
# eog c4b8ce1b67d38aa98345f108f9f529ca
# gps c6e285907444ace4568ae3dfaaac78da
# ddt c6e285907444ace4568ae3dfaaac78da
# dby c6e285907444ace4568ae3dfaaac78da
# iiu c6fac1b43c0b97c1a80e11267cca23e9
# gbp c7020e1c8939626c1b93975b3837bbe5
# tjy c7020e1c8939626c1b93975b3837bbe5
# kbf c888f3dd6a385becf18970f14086b692
# vgx c888f3dd6a385becf18970f14086b692
# aas c888f3dd6a385becf18970f14086b692
# wrc c9a3639b57c741dcd0334c28032e4280
# dxw c9a3639b57c741dcd0334c28032e4280
# cxw c9a3639b57c741dcd0334c28032e4280
# uyx cb4273c4aaa94175d070e3fc521c19ba
# vbk cd8e67ef15114f06a34d85ae70a7b860
# tyt cdbecba26b7e90271ae37bebccb1c586
# ctt cdbecba26b7e90271ae37bebccb1c586
# yjo cdbecba26b7e90271ae37bebccb1c586
# gmz ce3849d38fe0cdd425447af46afb38e0
# ndg ce3849d38fe0cdd425447af46afb38e0
# dct d0fa644bf6f985bf21fa53b9b457a3c6
# knn d1103521468423cafc056738668101aa
# vfo d1103521468423cafc056738668101aa
# pre d1103521468423cafc056738668101aa
# knn d1103521468423cafc056738668101aa
# ldu d1ab69b7b609835d704f43331fc9d9cf
# bkd d1ab69b7b609835d704f43331fc9d9cf
# boj d28e52d1c918252a4bd35bc4ef59bd23
# bav d28e52d1c918252a4bd35bc4ef59bd23
# itc d28e52d1c918252a4bd35bc4ef59bd23
# aso d3045f458fdbd6c4d88ad5cac4e8f346
# sox d3045f458fdbd6c4d88ad5cac4e8f346
# oww d41671114a78f1fbc51f5e0077ef7f68
# muj d41671114a78f1fbc51f5e0077ef7f68
# slt d4ced0deefa2251bc6bab293566736f1
# ydv d4ced0deefa2251bc6bab293566736f1
# kry d4ced0deefa2251bc6bab293566736f1
# eeu d4ced0deefa2251bc6bab293566736f1
# cna d4ced0deefa2251bc6bab293566736f1
# syi d4ced0deefa2251bc6bab293566736f1
# edn d4ced0deefa2251bc6bab293566736f1
# gwt d4ced0deefa2251bc6bab293566736f1
# hhz d4ced0deefa2251bc6bab293566736f1
# lbx d4ced0deefa2251bc6bab293566736f1
# lll d59027c5e4c7d14fa758fc1475aef056
# dbi d59027c5e4c7d14fa758fc1475aef056
# nsb d62ec24d065e424dd816ce7828f62584
# tcx d62ec24d065e424dd816ce7828f62584
# vln d62ec24d065e424dd816ce7828f62584
# tji d62ec24d065e424dd816ce7828f62584
# cdg d62ec24d065e424dd816ce7828f62584
# umv d62ec24d065e424dd816ce7828f62584
# aue d62ec24d065e424dd816ce7828f62584
# nov d62ec24d065e424dd816ce7828f62584
# fbk d82d330034189700983ffe50acc7e04b
# jmr db53556dc7a82a91a177ae3effe12015
# kaq dbabb977cec6af84577d101d6053b0b1
# iya dbabb977cec6af84577d101d6053b0b1
# fka dbabb977cec6af84577d101d6053b0b1
# tbs dbabb977cec6af84577d101d6053b0b1
# ayb dbabb977cec6af84577d101d6053b0b1
# akd dbabb977cec6af84577d101d6053b0b1
# uxc dbabb977cec6af84577d101d6053b0b1
# tgm dbabb977cec6af84577d101d6053b0b1
# tgm dbabb977cec6af84577d101d6053b0b1
# ggd dbabb977cec6af84577d101d6053b0b1
# urm dca66d38fd916317687e1390a420c3fc
# fyj dca66d38fd916317687e1390a420c3fc
# ait dd69b4a1513c9de9f46faf24048da1e8
# tmp dd69b4a1513c9de9f46faf24048da1e8
# gbv dd69b4a1513c9de9f46faf24048da1e8
# ezc dd69b4a1513c9de9f46faf24048da1e8
# nlw dd69b4a1513c9de9f46faf24048da1e8
# nmb dd69b4a1513c9de9f46faf24048da1e8
# vng dd69b4a1513c9de9f46faf24048da1e8
# oxx dd69b4a1513c9de9f46faf24048da1e8
# dpf dd69b4a1513c9de9f46faf24048da1e8
# bdz dd69b4a1513c9de9f46faf24048da1e8
# ntm dd84f8c3b293ff0fbe99bde56bbbb88e
# hks dd84f8c3b293ff0fbe99bde56bbbb88e
# wpg dd84f8c3b293ff0fbe99bde56bbbb88e
# oaz decc1f4d746b186716320cbe59145137
# ksr dfdb73449fe2b136ac55f7341b197376
# agf dfdb73449fe2b136ac55f7341b197376
# vep e1411a9602d4571d98b1f85aeb3a3e75
# ocr e1411a9602d4571d98b1f85aeb3a3e75
# agh e1411a9602d4571d98b1f85aeb3a3e75
# alq e1411a9602d4571d98b1f85aeb3a3e75
# ajl e2819fd981ac0f52db7e7787a6df76fc
# kmo e2c6517f142fe3a9e64e2a125e6ea602
# ctu e2c6517f142fe3a9e64e2a125e6ea602
# asn e2c6517f142fe3a9e64e2a125e6ea602
# vsb e2c6517f142fe3a9e64e2a125e6ea602
# uvm e30a8257ef313e3996831d16bbb336d6
# zqw e30a8257ef313e3996831d16bbb336d6
# mtx e31e1cd693159fc458cb7ca71f4d4af5
# ezb e31e1cd693159fc458cb7ca71f4d4af5
# fzd e31e1cd693159fc458cb7ca71f4d4af5
# ovm e31e1cd693159fc458cb7ca71f4d4af5
# ztv e31e1cd693159fc458cb7ca71f4d4af5
# ztv e31e1cd693159fc458cb7ca71f4d4af5
# gty e31e1cd693159fc458cb7ca71f4d4af5
# jyp e31e1cd693159fc458cb7ca71f4d4af5
# olr e31e1cd693159fc458cb7ca71f4d4af5
# zcg e31e1cd693159fc458cb7ca71f4d4af5
# wvq e31e1cd693159fc458cb7ca71f4d4af5
# zcg e31e1cd693159fc458cb7ca71f4d4af5
# eoo e535ed5534cb3315a374d5cfa6d1a1ad
# ljv e535ed5534cb3315a374d5cfa6d1a1ad
# xjv e54bbb8741d55358e5860639bb69dab2
# xch e54bbb8741d55358e5860639bb69dab2
# gsi e54bbb8741d55358e5860639bb69dab2
# aqk e54bbb8741d55358e5860639bb69dab2
# pag e5933f2aa258ba6a7966fde2446c0ab6
# bcy e5933f2aa258ba6a7966fde2446c0ab6
# wib e64226bc1d920bde84b4df22bce32c47
# gby e64226bc1d920bde84b4df22bce32c47
# lxo e6b492da244632e2e312fccf71cbda09
# lho e6b492da244632e2e312fccf71cbda09
# zbe e6b492da244632e2e312fccf71cbda09
# dae e6b492da244632e2e312fccf71cbda09
# muw e6b492da244632e2e312fccf71cbda09
# kys e6dc3d12efda69731159aa27268daf8d
# xmb e6dc3d12efda69731159aa27268daf8d
# exw e6dc3d12efda69731159aa27268daf8d
# xro e717cfe9d1ca2a2245d838567640a326
# jti e717cfe9d1ca2a2245d838567640a326
# bre e717cfe9d1ca2a2245d838567640a326
# blk e717cfe9d1ca2a2245d838567640a326
# gng e73716f50b6a127c919198d931d06011
# ckx e73716f50b6a127c919198d931d06011
# fqs e73716f50b6a127c919198d931d06011
# afo e73716f50b6a127c919198d931d06011
# ied e73716f50b6a127c919198d931d06011
# qet e73716f50b6a127c919198d931d06011
# fem e73716f50b6a127c919198d931d06011
# gxy e73716f50b6a127c919198d931d06011
# jfl e73716f50b6a127c919198d931d06011
# lrn e7501301ee20d8ce33016bbda86f0951
# tlq e7501301ee20d8ce33016bbda86f0951
# vqi e759e9c488c8723b68ea06bb653710f1
# tey e759e9c488c8723b68ea06bb653710f1
# vjw e759e9c488c8723b68ea06bb653710f1
# zei e759e9c488c8723b68ea06bb653710f1
# qsq e759e9c488c8723b68ea06bb653710f1
# vyf e796f186cd313102b7fc496da29da279
# ywi e796f186cd313102b7fc496da29da279
# cor e796f186cd313102b7fc496da29da279
# twk e796f186cd313102b7fc496da29da279
# rcl e796f186cd313102b7fc496da29da279
# bdh e7f2d9f8decb1e6da93206e54e505a62
# pso e7f2d9f8decb1e6da93206e54e505a62
# whn e81e8789f326cc3d9925e5a2de04e50e
# kgq e81e8789f326cc3d9925e5a2de04e50e
# dwe e9060e1816f638c09b686157164d013b
# gyi e9060e1816f638c09b686157164d013b
# ovk e9060e1816f638c09b686157164d013b
# lie e9060e1816f638c09b686157164d013b
# aoi e9060e1816f638c09b686157164d013b
# ndp e9060e1816f638c09b686157164d013b
# qso e9935ca937c809ae406fa3251b1e56ad
# nmj ea702ba4205cb37a88cc84851690a7a5
# oro ea702ba4205cb37a88cc84851690a7a5
# gco ea702ba4205cb37a88cc84851690a7a5
# ole ea702ba4205cb37a88cc84851690a7a5
# cdx ea702ba4205cb37a88cc84851690a7a5
# ksa ebce393760a7af1863cbfbbeb9f21c5e
# huu ebce393760a7af1863cbfbbeb9f21c5e
# hzx ebce393760a7af1863cbfbbeb9f21c5e
# dei ec138c07586544035f5e3547eb8cf4b2
# vbo ec138c07586544035f5e3547eb8cf4b2
# ygr f04ac234da586c07d5b415bd14fa01a6
# qcr f04ac234da586c07d5b415bd14fa01a6
# lix f11ff2edc86899fac53537a311156665
# xsr f11ff2edc86899fac53537a311156665
# ikf f11ff2edc86899fac53537a311156665
# sfe f11ff2edc86899fac53537a311156665
# ixv f11ff2edc86899fac53537a311156665
# hfh f11ff2edc86899fac53537a311156665
# hse f14626796f9fecbc1dd26432e3df5adc
# rxj f171683b7d999c1ad1598da5eee0f70a
# zwk f171683b7d999c1ad1598da5eee0f70a
# kjv f171683b7d999c1ad1598da5eee0f70a
# ujx f171683b7d999c1ad1598da5eee0f70a
# nhv f171683b7d999c1ad1598da5eee0f70a
# itx f1b5c85a74101d751deeec43b7717f6b
# fne f1b5c85a74101d751deeec43b7717f6b
# jvm f1b5c85a74101d751deeec43b7717f6b
# yrv f57475361e6c79ab518923d4a68550fb
# ich f8338289f2de14ec4e2d7842d40fc84e
# onc f8338289f2de14ec4e2d7842d40fc84e
# tlx fbc978727dccc257765b97a7b662963e
# yll fbc978727dccc257765b97a7b662963e
# eho fe02de679c1eb64620041678470ab05c
# gjr fe02de679c1eb64620041678470ab05c
# qxl fe02de679c1eb64620041678470ab05c
# coh fe02de679c1eb64620041678470ab05c
# vsa fe02de679c1eb64620041678470ab05c
# tpk fe02de679c1eb64620041678470ab05c
# rdi fe02de679c1eb64620041678470ab05c
# tye fe875be3377cc3eadede0e56364f5b06
# pov ffd93b30364fb8893d5bbb6fdb312666
# gyj ffd93b30364fb8893d5bbb6fdb312666
# whd ffd93b30364fb8893d5bbb6fdb312666
# bzh ffd93b30364fb8893d5bbb6fdb312666
# jen ffd93b30364fb8893d5bbb6fdb312666
# >
