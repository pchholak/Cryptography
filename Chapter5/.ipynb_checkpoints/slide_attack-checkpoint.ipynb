# %%
from easy1 import encrypt, mux, demux, sbox, pbox

# %%
def f_spn(p):
    u = []
    # Run through the s-boxes
    for x in demux(p):
        u.append(sbox(x))
    # Run through the p-box and return
    return pbox(mux(u))

# %%
# Read the file with PT-CT pairs
PC = []
pairs_file = "plain-cipher.txt"
f = open(pairs_file, "r")
line = f.readline()
while line != '':
    pt, ct = line.strip().split(sep=" ", maxsplit=1)
    PC.append((int(pt), int(ct)))
    line = f.readline()
f.close()

# %%
# PC = PC[:100]

# %%
for inx, pair in enumerate(PC):
    print('Running pair# %d out of %d pairs' % (inx+1, len(PC)))
    p, c = pair
    fp, fc = f_spn(p), f_spn(c)
    PC_copy = PC.copy()
    PC_copy.remove(pair)
    for q, d in PC_copy:
        if fp ^ q == fc ^ d:
            print('Checking for collision')
            k = (fp ^ q) & 0xfffffffff
            print("Key:", k)
            if encrypt(p, 20, k) == c:
                print('Found key!')
                break
            else:
                print('False positive!')
# Out:
# Running pair# 1 out of 100 pairs
# Running pair# 2 out of 100 pairs
# Running pair# 3 out of 100 pairs
# Running pair# 4 out of 100 pairs
# Running pair# 5 out of 100 pairs
# Running pair# 6 out of 100 pairs
# Running pair# 7 out of 100 pairs
# Running pair# 8 out of 100 pairs
# Running pair# 9 out of 100 pairs
# Running pair# 10 out of 100 pairs
# Running pair# 11 out of 100 pairs
# Running pair# 12 out of 100 pairs
# Running pair# 13 out of 100 pairs
# Running pair# 14 out of 100 pairs
# Running pair# 15 out of 100 pairs
# Running pair# 16 out of 100 pairs
# Running pair# 17 out of 100 pairs
# Running pair# 18 out of 100 pairs
# Running pair# 19 out of 100 pairs
# Running pair# 20 out of 100 pairs
# Running pair# 21 out of 100 pairs
# Running pair# 22 out of 100 pairs
# Running pair# 23 out of 100 pairs
# Running pair# 24 out of 100 pairs
# Running pair# 25 out of 100 pairs
# Running pair# 26 out of 100 pairs
# Running pair# 27 out of 100 pairs
# Running pair# 28 out of 100 pairs
# Running pair# 29 out of 100 pairs
# Running pair# 30 out of 100 pairs
# Running pair# 31 out of 100 pairs
# Running pair# 32 out of 100 pairs
# Running pair# 33 out of 100 pairs
# Running pair# 34 out of 100 pairs
# Running pair# 35 out of 100 pairs
# Running pair# 36 out of 100 pairs
# Running pair# 37 out of 100 pairs
# Running pair# 38 out of 100 pairs
# Running pair# 39 out of 100 pairs
# Running pair# 40 out of 100 pairs
# Running pair# 41 out of 100 pairs
# Running pair# 42 out of 100 pairs
# Running pair# 43 out of 100 pairs
# Running pair# 44 out of 100 pairs
# Running pair# 45 out of 100 pairs
# Running pair# 46 out of 100 pairs
# Running pair# 47 out of 100 pairs
# Running pair# 48 out of 100 pairs
# Running pair# 49 out of 100 pairs
# Running pair# 50 out of 100 pairs
# Running pair# 51 out of 100 pairs
# Running pair# 52 out of 100 pairs
# Running pair# 53 out of 100 pairs
# Running pair# 54 out of 100 pairs
# Running pair# 55 out of 100 pairs
# Running pair# 56 out of 100 pairs
# Running pair# 57 out of 100 pairs
# Running pair# 58 out of 100 pairs
# Running pair# 59 out of 100 pairs
# Running pair# 60 out of 100 pairs
# Running pair# 61 out of 100 pairs
# Running pair# 62 out of 100 pairs
# Running pair# 63 out of 100 pairs
# Running pair# 64 out of 100 pairs
# Running pair# 65 out of 100 pairs
# Running pair# 66 out of 100 pairs
# Running pair# 67 out of 100 pairs
# Running pair# 68 out of 100 pairs
# Running pair# 69 out of 100 pairs
# Running pair# 70 out of 100 pairs
# Running pair# 71 out of 100 pairs
# Running pair# 72 out of 100 pairs
# Running pair# 73 out of 100 pairs
# Running pair# 74 out of 100 pairs
# Running pair# 75 out of 100 pairs
# Running pair# 76 out of 100 pairs
# Running pair# 77 out of 100 pairs
# Running pair# 78 out of 100 pairs
# Running pair# 79 out of 100 pairs
# Running pair# 80 out of 100 pairs
# Running pair# 81 out of 100 pairs
# Running pair# 82 out of 100 pairs
# Running pair# 83 out of 100 pairs
# Running pair# 84 out of 100 pairs
# Running pair# 85 out of 100 pairs
# Running pair# 86 out of 100 pairs
# Running pair# 87 out of 100 pairs
# Running pair# 88 out of 100 pairs
# Running pair# 89 out of 100 pairs
# Running pair# 90 out of 100 pairs
# Running pair# 91 out of 100 pairs
# Running pair# 92 out of 100 pairs
# Running pair# 93 out of 100 pairs
# Running pair# 94 out of 100 pairs
# Running pair# 95 out of 100 pairs
# Running pair# 96 out of 100 pairs
# Running pair# 97 out of 100 pairs
# Running pair# 98 out of 100 pairs
# Running pair# 99 out of 100 pairs
# Running pair# 100 out of 100 pairs
