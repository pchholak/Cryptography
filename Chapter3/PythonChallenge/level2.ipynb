# %%
from selenium import webdriver
import nltk

# %%
current_url = 'http://www.pythonchallenge.com/pc/def/ocr.html'

# %%
driver = webdriver.Chrome(
    'C:/Users/Usuario/Python/Cryptanalysis/Chapter3/PythonChallenge/chromedriver_win32/chromedriver.exe')

# %%
# driver.get(current_url)
# html = driver.page_source
# print(html)

# %%
# file = open("level2_page_src.txt", "w")
# file.write(html)
# file.close()

# %%
file = open("level2_character_mess.txt", "r")
chars = file.read()
print(chars)
# Out:
# %%$@_$^__#)^)&!_+]!*@&^}@[@%]()%+$&[(_@%+%$*^@$^!+]!&_#)_*}{}}!}_]$[%}@[{_@#_^{*
# @##&{#&{&)*%(]{{([*}@[@&]+!!*{)!}{%+{))])[!^})+)$]#{*+^((@^@}$[**$&^{$!@#$%)!@(&
# +^!{%_$&@^!}$_${)$_#)!({@!)(^}!*^&!$%_&&}&_#&@{)]{+)%*{&*%*&@%$+]!*__(#!*){%&@++
# !_)^$&&%#+)}!@!)&^}**#!_$([$!$}#*^}$+&#[{*{}{((#$]{[$[$$()_#}!@}^@_&%^*!){*^^_$^
# ]@}#%[%!^[^_})+@&}{@*!(@$%$^)}[_!}(*}#}#___}!](@_{{(*#%!%%+*)^+#%}$+_]#}%!**#!^_
# )@)$%%^{_%!@(&{!}$_$[)*!^&{}*#{!)@})!*{^&[&$#@)*@#@_@^_#*!@_#})+[^&!@*}^){%%{&#@
# @{%(&{+(#^{@{)%_$[+}]$]^{^#(*}%)@$@}(#{_&]#%#]{_*({(])$%[!}#@@&_)([*]}$}&${^}@(%
# (%[@%!}%*$}(*@)}){+@(%@*$&]*^*}*]&$[}*]%]+*}^!}*$^^_()#$^]++@__){&&+((#%+(&+){)$
# %&&#($[[+##*%${)_!+{_[})%++)$#))]]]$]@]@($+{&%&%+!!!@]_]+])^*@$(@#${}}#}{%}#+{(@
# #__+{{]${]!{(%${%%^)(_*_@+)$]$#_@$)]](}{}$(}*%+!}#+)$%$}+#@*&^{##}+@(%[*@_}{(^]^
# +_*{@+[$!!@%$+{_&(#^(([&[][[&@#+}_]&&]}^*&$&)#_^$@$((%)}+{}$#+{+^}&[#[#_+${#[#]{
# (@@[%}[}$%+*#$+[%(**!$+@$@&+$_$#!_&&&&{***+)}][}#^!%#&$*)$!%}*&#}}##(^_%^]{+]&&]
# ...

# %%
char_list = [c for c in chars]
fdist = nltk.FreqDist(char_list)
fdist.most_common()
# Out:
# [(')', 6186),
#  ('@', 6157),
#  ('(', 6154),
#  (']', 6152),
#  ('#', 6115),
#  ('_', 6112),
#  ('[', 6108),
#  ('}', 6105),
#  ('%', 6104),
#  ('!', 6079),
#  ('+', 6066),
#  ('$', 6046),
#  ('{', 6046),
#  ('&', 6043),
#  ('*', 6034),
#  ('^', 6030),
#  ('\n', 1219),
#  ('e', 1),
#  ('q', 1),
#  ('u', 1),
#  ('a', 1),
#  ('l', 1),
#  ('i', 1),
#  ('t', 1),
#  ('y', 1)]

# %%
url_comp = current_url.split('/')
ext = url_comp[-1][-5:]

# %%
url_new_comp = url_comp[:-1]
url_new_comp.append('equality' + ext)
url_new_joined = '/'.join(url_new_comp)
url_new_joined
# Out:
# 'http://www.pythonchallenge.com/pc/def/equality.html'
